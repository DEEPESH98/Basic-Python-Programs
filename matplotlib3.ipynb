# %% [markdown]
# <a href="https://colab.research.google.com/github/DEEPESH98/Basic-Python-Programs/blob/master/matplotlib3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
#only loading python orfiented libary


x=[2,3]
x1=[4,3,8]
y1=[2,9,7]
y=[9,5]

#plt.xlabel("time")
#plt.ylabel("speed")
plt.plot(x,y) # plot funtion dono jode ke state line bana ta he
plt.plot(x1,y1)
#plt.bar(x1,y1,color="pink")
#plt.grid(color="green")
#plt.legend() # to show lables with plot
#plt.xlim(0,12) # TO SHOW MIN and max number in axis
#plt.ylim(0,15)
#plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('bank.csv')

#df.info()

df
#plt.plot(df)
# Out:
#       RowNumber  CustomerId  ... EstimatedSalary  Exited
# 0             1    15634602  ...       101348.88       1
# 1             2    15647311  ...       112542.58       0
# 2             3    15619304  ...       113931.57       1
# 3             4    15701354  ...        93826.63       0
# 4             5    15737888  ...        79084.10       0
# 5             6    15574012  ...       149756.71       1
# 6             7    15592531  ...        10062.80       0
# 7             8    15656148  ...       119346.88       1
# 8             9    15792365  ...        74940.50       0
# 9            10    15592389  ...        71725.73       0
# 10           11    15767821  ...        80181.12       0
# 11           12    15737173  ...        76390.01       0
# 12           13    15632264  ...        26260.98       0
# 13           14    15691483  ...       190857.79       0
# 14           15    15600882  ...        65951.65       0
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import time

x=[4,7,8,9,11,5]
y=[13,23,5,7,9,6]
player=['virat','dhoni','vijay','dhawan']
runs=[120,130,150,33]
exp=[0.1,1,2,0.2]

#plt.xlabel("x-axis")
#plt.ylabel("y-axis")
plt.pie(runs,labels=player,explode=exp,shadow=True,autopct='%1.1f%%')
plt.grid(color='green')
#plt.legend() # to show lables with plot
plt.show()
